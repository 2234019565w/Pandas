# %%
import pandas as pd
import time, datetime
import numpy as np

# %%
df_mov = pd.read_csv('movies.csv')
df_rat = pd.read_csv('ratings.csv')
df_tag = pd.read_csv('tags.csv')

# %%
df_rat.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_mov.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tag.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
temp = pd.merge(df_mov,df_rat,left_on = 'movieId',right_on = 'movieId')

# %%
temp.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
total = pd.merge(temp,df_tag,left_on= 'movieId',right_on = 'movieId')

# %%
total.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId_x  rating  timestamp_x  userId_y    tag  timestamp_y
# 0         1     4.0    964982703       336  pixar   1139045764
# 1         1     4.0    964982703       474  pixar   1137206825
# 2         1     4.0    964982703       567    fun   1525286013
# 3         5     4.0    847434962       336  pixar   1139045764
# 4         5     4.0    847434962       474  pixar   1137206825

# %%
CSV = total.loc[:,['movieId','title','rating','tag','genres']]

# %%
CSV.head()
# Out:
#    movieId             title  rating    tag  \
# 0        1  Toy Story (1995)     4.0  pixar
# 1        1  Toy Story (1995)     4.0  pixar
# 2        1  Toy Story (1995)     4.0    fun
# 3        1  Toy Story (1995)     4.0  pixar
# 4        1  Toy Story (1995)     4.0  pixar
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy
